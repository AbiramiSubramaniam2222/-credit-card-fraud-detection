# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("creditcard.csv")

# %%
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5     2 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6     4  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7     7 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8     7 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9     9 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df["Class"].value_counts()
# Out:
# Class
# 0.0    19812
# 1.0       85
# Name: count, dtype: int64

# %%
df["Class"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# Class 0- Normal Transaction. This means the transaction appears to be made by the actual cardholder, with no suspicious or fraudulent behavior detected.
# Class 1 - Fradulent Transaction.  This flags the transaction as likely made by someone who is not authorized to use the card—possibly due to stolen card details or some malicious activity.

# %%
fraud_transactions=df[df["Class"]==1]
print(fraud_transactions)
# Out:
#         Time         V1         V2         V3        V4         V5        V6  \
# 541      406  -2.312227   1.951992  -1.609851  3.997906  -0.522188 -1.426545
# 623      472  -3.043541  -3.157307   1.088463  2.288644   1.359805 -1.064823
# 4920    4462  -2.303350   1.759247  -0.359745  2.330243  -0.821628 -0.075788
# 6108    6986  -4.397974   1.358367  -2.592844  2.679787  -1.128131 -1.706536
# 6329    7519   1.234235   3.019740  -4.304597  4.732795   3.624201 -1.357746
# ...      ...        ...        ...        ...       ...        ...       ...
# 17480  28755 -30.552380  16.713389 -31.103685  6.534984 -22.105532 -4.977692
# 18466  29526   1.102804   2.829168  -3.932870  4.707691   2.937967 -1.800904
# 18472  29531  -1.060676   2.608579  -2.971679  4.360089   3.738853 -2.728395
# 18773  29753   0.269614   3.549755  -5.810353  5.809370   1.538808 -2.269219
# 18809  29785   0.923764   0.344048  -2.880004  1.721680  -3.019565 -0.639736
#
# ...

# %%
sns.countplot(data=df,x="Class")
plt.title("Distribution of Class labels Fraud vs NonFraud")
plt.xlabel("Class(0=Non_Fraud, 1=Fraud)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Clearly it shows a imbalanced dataset

# %%
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline

# %%
df_combined = pd.concat([X, y], axis=1)

# Step 2: Drop rows where Class (y) is NaN
df_combined = df_combined.dropna(subset=["Class"])

# Step 3: Split them again
X = df_combined.drop("Class", axis=1)
y = df_combined["Class"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
print(y.isna().sum())
# Out:
# 0

# %%
scale_weight=len(y_train[y_train == 0]) / len(y_train[y_train == 1])

# %%
pipe=Pipeline([
    ("model",XGBClassifier(scale_pos_weight=scale_weight,
                          use_label_encorder=False,
                          eval_metric="logloss",
                          random_state=42))
])

# %%
pipe.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [07:22:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encorder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Pipeline(steps=[('model',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=None, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric='logloss',
#                                feature_types=None, gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
# ...

# %%
y_predict=pipe.predict(X_test)

# %%
print(classification_report(y_predict,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3964
#            1       0.82      0.88      0.85        16
#
#     accuracy                           1.00      3980
#    macro avg       0.91      0.94      0.92      3980
# weighted avg       1.00      1.00      1.00      3980

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
model_rf = RandomForestClassifier(class_weight='balanced',random_state=42)
model_lr = LogisticRegression()

# Fit on training data
model_rf.fit(X_train, y_train)
model_lr.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pred_rf = model_rf.predict_proba(X_test)[:, 1]
pred_lr = model_lr.predict_proba(X_test)[:, 1]

# %%
import numpy as np

# %%
stacked_X = np.column_stack((pred_rf, pred_lr))

# %%
meta_model = LogisticRegression()
meta_model.fit(stacked_X, y_test)
# Out:
# LogisticRegression()

# %%
test_rf = model_rf.predict_proba(X_test)[:, 1]
test_lr = model_lr.predict_proba(X_test)[:, 1]

# %%
final_pred = meta_model.predict(test_stacked)

# %%
test_stacked = np.column_stack((test_rf, test_lr))

# %%
test_stacked
# Out:
# array([[0.00000000e+00, 3.13868330e-07],
#        [0.00000000e+00, 6.87482934e-03],
#        [0.00000000e+00, 3.44428755e-06],
#        ...,
#        [0.00000000e+00, 1.95758095e-06],
#        [0.00000000e+00, 4.89349848e-10],
#        [0.00000000e+00, 5.50064302e-04]])

# %%
meta_model=XGBClassifier(use_label_encoder=False,eval_metric='logloss')

# %%
meta_model.fit(stacked_X,y_test)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, random_state=None, ...)

# %%
final_preds = meta_model.predict(test_stacked)

# %%
final_probs = meta_model.predict_proba(test_stacked)[:, 1]

# %%
final_probs
# Out:
# array([3.0330924e-04, 9.1288581e-05, 2.9162824e-04, ..., 2.9162824e-04,
#        1.7474883e-04, 9.1288581e-05], dtype=float32)
